# %% [markdown]
# ![2560px-D&d-3thedit-logo.svg.png](attachment:2560px-D&d-3thedit-logo.svg.png)

# %% [markdown]
# ***Project By:** Kay Crapoff, Mahjan "MJ" Rastegarlar, Noah Neuman, Zack Dorff*

# %% [markdown]
# **Data:** https://www.kaggle.com/datasets/patrickgomes/dungeons-and-dragons-5e-monsters

# %%
# Including needed packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Pull data from file and clean it up (Zack)
...

# %%
# Graph data to visualize it (Kay)
...

# %%
# Build Model (Noah)
...

# %%
# Train Model (Noah)
...

# %%
# Fit Model (MJ)
...

# %%
# Graph outcomes (Kay)
...
